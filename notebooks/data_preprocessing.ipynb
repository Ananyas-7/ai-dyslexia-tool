# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananyas-7/ai-dyslexia-tool/blob/main/notebooks/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet pdfplumber pandas nltk
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 58.0 MB/s eta 0:00:00

# %%
# !pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 66.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 49.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 17.6 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python-headless pillow

# %%
# !pip install pandas nltk scikit-learn

# %%
# !pip install gdown

# %%
from google.colab import files

uploaded = files.upload()  # this opens a file chooser
# Out:
#      <input type="file" id="files-e5a0368f-5258-4c18-8e86-fc8520893ff8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5a0368f-5258-4c18-8e86-fc8520893ff8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()  # this opens a file chooser
# Out:
#      <input type="file" id="files-e5c72358-681d-42bf-bfc8-15345ac7f7cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5c72358-681d-42bf-bfc8-15345ac7f7cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'cesa103.pdf', 'aemr104.pdf', 'cesa105.pdf', 'aemr108.pdf', 'aemr101.pdf', 'cesa106.pdf', 'cesa109.pdf', 'aemr106.pdf', 'cesa108.pdf', 'cesa110.pdf', 'cesa111.pdf', 'aemr1ps.pdf', 'aemr105.pdf', 'cesa104.pdf', 'aemr109.pdf', 'cesa102.pdf', 'aemr102.pdf', 'cesa107.pdf', 'cesa112.pdf', 'aemr107.pdf', 'aemr103.pdf', 'cesa101.pdf', 'aemr1cc.pdf', 'cesa1ps.pdf', 'sample_data']

# %%
# !pip install pdfplumber nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')   # <-- this fixes the error
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import pdfplumber
import pandas as pd
from nltk.tokenize import sent_tokenize
import nltk
import os

nltk.download('punkt')

pdf_folder = "/content"
all_sentences = []

# Loop through all PDF files
for file in os.listdir(pdf_folder):
    if file.endswith(".pdf"):
        path = os.path.join(pdf_folder, file)
        try:
            with pdfplumber.open(path) as pdf:
                for page in pdf.pages:
                    text = page.extract_text()
                    if text:
                        for sent in sent_tokenize(text):
                            sent = sent.strip()
                            if len(sent) > 3:  # filter out junk
                                all_sentences.append({"file": file, "sentence": sent})
        except Exception as e:
            print(f"⚠️ Could not process {file}: {e}")

# Save to CSV
df = pd.DataFrame(all_sentences)
df.to_csv("children_books_sentences.csv", index=False)
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# ...

# %%
import pdfplumber
import pandas as pd
from nltk.tokenize import sent_tokenize
import nltk
import os

# download required NLTK data
nltk.download('punkt')
nltk.download('punkt_tab')

pdf_folder = "/content"
all_sentences = []

for file in os.listdir(pdf_folder):
    if file.endswith(".pdf"):
        path = os.path.join(pdf_folder, file)
        try:
            with pdfplumber.open(path) as pdf:
                for page in pdf.pages:
                    text = page.extract_text()
                    if text:
                        for sent in sent_tokenize(text):
                            sent = sent.strip()
                            if len(sent) > 3:
                                all_sentences.append({"file": file, "sentence": sent})
        except Exception as e:
            print(f"⚠️ Skipped {file}: {e}")

# Save results
df = pd.DataFrame(all_sentences)
df.to_csv("children_books_sentences.csv", index=False)
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray stroke color because /'P0' is an invalid float value
# ...

# %%
# Clean text: remove newlines and extra spaces
df["sentence"] = df["sentence"].str.replace(r"\s+", " ", regex=True).str.strip()

# Save cleaned dataset
df.to_csv("children_books_sentences_clean.csv", index=False)
df.head(10)
# Out:
#           file                                           sentence
# 0  cesa103.pdf  Best Friends Chapter LLeett uuss rreeaadd Ther...
# 1  cesa103.pdf   One day there began a fight between the friends.
# 2  cesa103.pdf              Each of them said they were the best.
# 3  cesa103.pdf                       Circle said, “I am the best!
# 4  cesa103.pdf                          I am round and beautiful.
# 5  cesa103.pdf                             I have no sharp edges.
# 6  cesa103.pdf            Children use me to draw a smiling face.
# 7  cesa103.pdf    There are so many beautiful things in my shape.
# 8  cesa103.pdf  I am the best!” Reprint 2025-26 UUnniitt 11__E...
# 9  cesa103.pdf  The other shapes refused to agree with the cir...

# %%
df["simple_sentence"] = ""  # blank column for now
df.to_csv("children_books_dataset.csv", index=False)
df.head()
# Out:
#           file                                           sentence  \
# 0  cesa103.pdf  Best Friends Chapter LLeett uuss rreeaadd Ther...
# 1  cesa103.pdf   One day there began a fight between the friends.
# 2  cesa103.pdf              Each of them said they were the best.
# 3  cesa103.pdf                       Circle said, “I am the best!
# 4  cesa103.pdf                          I am round and beautiful.
#
#   simple_sentence
# 0
# 1
# 2
# 3
# 4

# %%
print("Total sentences extracted:", len(df))
print(df.sample(10))  # show 10 random sentences
# Out:
# Total sentences extracted: 2459
#              file                                           sentence  \
# 2044  cesa112.pdf  126 Santoor │ Class 3 Reprint 2025-26 UUnniitt...
# 986   cesa108.pdf      Why did the farmer decide to take the grapes?
# 1340  aemr105.pdf  Let us do Colour the farm and name the animals...
# 399   aemr108.pdf                    (a) What do you wear in summer?
# 2218  cesa101.pdf  Reprint 2025-26 UUnniitt 11__EEnngglliisshh..i...
# 135   aemr104.pdf  Chapter 2 Let us read The Cap-seller and the M...
# 301   cesa105.pdf  I think they would like to fly me,” said the a...
# 483   aemr101.pdf  Mridang 5 Reprint 2025-26 CChhaapptteerr 11..i...
# 2221  cesa101.pdf              Write your answer in the given space.
# 330   cesa105.pdf  Add a word from the help box to the given nami...
#
#      simple_sentence
# 2044
# 986
# 1340
# 399
# 2218
# 135
# 301
# 483
# 2221
# 330

# %%
import os
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split

# Download NLTK resources
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")

# Initialize tools
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

# -------------------------------
# Step 1: Text cleaning
# -------------------------------
def clean_text(text):
    if not isinstance(text, str):
        return ""
    # Remove line breaks and multiple spaces
    text = text.replace("\n", " ")
    text = " ".join(text.split())
    return text.strip()

# -------------------------------
# Step 2: Tokenization + normalization
# -------------------------------
def tokenize_text(text):
    tokens = word_tokenize(text)   # word-level tokenization
    tokens = [t.lower() for t in tokens if t.isalpha()]  # keep words only
    tokens = [lemmatizer.lemmatize(t) for t in tokens]   # lemmatization
    tokens = [t for t in tokens if t not in stop_words]  # remove stopwords
    return tokens

# -------------------------------
# Step 3: Preprocess dataset
# -------------------------------
def preprocess_dataset(input_path, output_dir="data/processed"):
    os.makedirs(output_dir, exist_ok=True)

    # Load dataset
    df = pd.read_csv(input_path)

    # Clean sentences
    df["complex_sentence"] = df["sentence"].apply(clean_text)

    # Tokenize (optional: store as space-separated tokens)
    df["tokens"] = df["complex_sentence"].apply(lambda x: " ".join(tokenize_text(x)))

    # Add placeholder for simplified sentence
    if "simple_sentence" not in df.columns:
        df["simple_sentence"] = ""

    # Train/val/test split
    train, temp = train_test_split(df, test_size=0.3, random_state=42)
    val, test = train_test_split(temp, test_size=0.5, random_state=42)

    # Save outputs
    train.to_csv(os.path.join(output_dir, "train.csv"), index=False)
    val.to_csv(os.path.join(output_dir, "val.csv"), index=False)
    test.to_csv(os.path.join(output_dir, "test.csv"), index=False)

    print(f"✅ Saved processed datasets in {output_dir}")
    print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")

    return train, val, test

# -------------------------------
# Run preprocessing
# -------------------------------
train, val, test = preprocess_dataset("children_books_sentences_clean.csv")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ✅ Saved processed datasets in data/processed
# Train: 1721, Val: 369, Test: 369

# %%
import pandas as pd

# Load processed datasets
train = pd.read_csv("data/processed/train.csv")
val = pd.read_csv("data/processed/val.csv")
test = pd.read_csv("data/processed/test.csv")

# Print dataset sizes
print("Train size:", len(train))
print("Validation size:", len(val))
print("Test size:", len(test))

# Show some examples from train
print("\n🔹 Train sample:")
print(train.head(10))

# Show some random validation examples
print("\n🔹 Validation sample:")
print(val.sample(5, random_state=42))

# Show some random test examples
print("\n🔹 Test sample:")
print(test.sample(5, random_state=42))
# Out:
# Train size: 1721
# Validation size: 369
# Test size: 369
#
# 🔹 Train sample:
#           file                                           sentence  \
# 0  aemr104.pdf  For example Butterflies, (clap) butterflies, (...
# 1  cesa109.pdf  Note to the teacher • Draw learners’ attention...
# 2  cesa108.pdf        There ______________ animals in the jungle.
# 3  cesa109.pdf                                     I eat a peach.
# 4  cesa106.pdf                       What was Meena playing with?
# 5  cesa105.pdf                                 Draw or trace a 3.
# 6  cesa106.pdf  As the boats floated down the stream, she saw ...
# 7  cesa108.pdf  I had grown the best grapes and watermelons on...
# 8  aemr106.pdf                                  Are these onions?
# 9  aemr105.pdf                                     This is a rat.
#
#                                     complex_sentence  \
# 0  For example Butterflies, (clap) butterflies, (...
# 1  Note to the teacher • Draw learners’ attention...
# ...
